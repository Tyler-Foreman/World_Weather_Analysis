# %%
# Import our dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitudes and longitudes

lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-90.000,90.000,size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create an empty list to hold cities
cities = []
# Identify the nearest city using latitude and longitude 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
# Build URL to call OpenWeather API
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# Create an empty list to hold city weather data
city_data = []

# Print the beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL for each city
    city_url = base_url + '&q=' + city.replace(' ','+')
    
    # Log the URL, record, and set numbers and the city.
    print(f'Processing record {record_count} of set {set_count} | {city}')
    
    # Add the record count by 1
    record_count += 1
    
    # Run an API request for each city
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the data we need
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        # Append the city information into the city_data list
        city_data.append({'City' : city.title(),
                          'Country' : city_country,
                          'Lat' : city_lat,
                          'Lng' : city_lng,
                          'Max Temp' : city_max_temp,
                          'Humidity' : city_humidity,
                          'Cloudiness' : city_clouds,
                          'Wind Speed' : city_wind,
                          'Current Description' : city_description})
    
    # If an error is experienced
    except:
        print(f' {city} was not found. Skipping...')
        pass
    
# Indicate that data retrieval is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | muskegon
# Processing record 2 of set 1 | jamestown
# Processing record 3 of set 1 | faya
# Processing record 4 of set 1 | ushuaia
# Processing record 5 of set 1 | hermanus
# Processing record 6 of set 1 | buqayq
#  buqayq was not found. Skipping...
# Processing record 7 of set 1 | punta arenas
# Processing record 8 of set 1 | kuryk
# Processing record 9 of set 1 | west bay
# Processing record 10 of set 1 | puerto colombia
# Processing record 11 of set 1 | valdivia
# Processing record 12 of set 1 | warqla
#  warqla was not found. Skipping...
# Processing record 13 of set 1 | barentsburg
#  barentsburg was not found. Skipping...
# Processing record 14 of set 1 | cape town
# Processing record 15 of set 1 | roald
# Processing record 16 of set 1 | pasni
# Processing record 17 of set 1 | camocim
# Processing record 18 of set 1 | illoqqortoormiut
#  illoqqortoormiut was not found. Skipping...
# Processing record 19 of set 1 | busselton
# Processing record 20 of set 1 | taolanaro
#  taolanaro was not found. Skipping...
# Processing record 21 of set 1 | dolores
# Processing record 22 of set 1 | saint-philippe
# Processing record 23 of set 1 | tsihombe
#  tsihombe was not found. Skipping...
# Processing record 24 of set 1 | port alfred
# Processing record 25 of set 1 | cambridge
# Processing record 26 of set 1 | ponta do sol
# Processing record 27 of set 1 | alto araguaia
# Processing record 28 of set 1 | comodoro rivadavia
# Processing record 29 of set 1 | eyl
# Processing record 30 of set 1 | rawson
# Processing record 31 of set 1 | vrede
# Processing record 32 of set 1 | dikson
# Processing record 33 of set 1 | tromso
# Processing record 34 of set 1 | belushya guba
#  belushya guba was not found. Skipping...
# Processing record 35 of set 1 | tandil
# Processing record 36 of set 1 | ancud
# Processing record 37 of set 1 | mao
# Processing record 38 of set 1 | cidreira
# Processing record 39 of set 1 | oksfjord
# Processing record 40 of set 1 | mar del plata
# Processing record 41 of set 1 | saldanha
# Processing record 42 of set 1 | nantucket
# Processing record 43 of set 1 | bredasdorp
# Processing record 44 of set 1 | san cristobal
# Processing record 45 of set 1 | crestview
# Processing record 46 of set 1 | sedelnikovo
#  sedelnikovo was not found. Skipping...
# Processing record 47 of set 1 | chuy
# Processing record 48 of set 1 | sebina
# Processing record 49 of set 1 | zemio
# Processing record 50 of set 1 | puerto madryn
# Processing record 1 of set 2 | gwadar
# Processing record 2 of set 2 | hun
# Processing record 3 of set 2 | san luis
# Processing record 4 of set 2 | kaura namoda
# Processing record 5 of set 2 | zitsa
# Processing record 6 of set 2 | awjilah
# Processing record 7 of set 2 | henties bay
# Processing record 8 of set 2 | qaanaaq
# Processing record 9 of set 2 | harper
# Processing record 10 of set 2 | amderma
#  amderma was not found. Skipping...
# Processing record 11 of set 2 | umm durman
#  umm durman was not found. Skipping...
# Processing record 12 of set 2 | ribeira grande
# Processing record 13 of set 2 | krasnoarmeysk
# Processing record 14 of set 2 | beboto
# Processing record 15 of set 2 | nanortalik
# Processing record 16 of set 2 | gaoual
# Processing record 17 of set 2 | lagoa
# Processing record 18 of set 2 | namibe
# Processing record 19 of set 2 | puerto cortes
#  puerto cortes was not found. Skipping...
# Processing record 20 of set 2 | souillac
# Processing record 21 of set 2 | burica
#  burica was not found. Skipping...
# Processing record 22 of set 2 | conceicao do araguaia
# Processing record 23 of set 2 | narsaq
# Processing record 24 of set 2 | ati
# Processing record 25 of set 2 | marcona
#  marcona was not found. Skipping...
# Processing record 26 of set 2 | laguna
# Processing record 27 of set 2 | grand river south east
#  grand river south east was not found. Skipping...
# Processing record 28 of set 2 | gat
# Processing record 29 of set 2 | salinas
# Processing record 30 of set 2 | guajara-mirim
#  guajara-mirim was not found. Skipping...
# Processing record 31 of set 2 | placido de castro
# Processing record 32 of set 2 | voskresenskoye
# Processing record 33 of set 2 | torbay
# Processing record 34 of set 2 | yenagoa
# Processing record 35 of set 2 | mahebourg
# Processing record 36 of set 2 | andra
# Processing record 37 of set 2 | mahibadhoo
# Processing record 38 of set 2 | castro
# Processing record 39 of set 2 | castel volturno
# Processing record 40 of set 2 | codrington
# Processing record 41 of set 2 | edd
# Processing record 42 of set 2 | husavik
# Processing record 43 of set 2 | amapa
# Processing record 44 of set 2 | nortelandia
# Processing record 45 of set 2 | sorland
# Processing record 46 of set 2 | taoudenni
# Processing record 47 of set 2 | luderitz
# Processing record 48 of set 2 | tumannyy
#  tumannyy was not found. Skipping...
# Processing record 49 of set 2 | sao joao da barra
# Processing record 50 of set 2 | upernavik
# Processing record 1 of set 3 | saint-leu
# Processing record 2 of set 3 | arraial do cabo
# Processing record 3 of set 3 | havelock
# Processing record 4 of set 3 | hadejia
# Processing record 5 of set 3 | hofn
# Processing record 6 of set 3 | kruisfontein
# Processing record 7 of set 3 | georgetown
# Processing record 8 of set 3 | turayf
# Processing record 9 of set 3 | monrovia
# Processing record 10 of set 3 | buraydah
# Processing record 11 of set 3 | bambous virieux
# Processing record 12 of set 3 | east london
# Processing record 13 of set 3 | braniewo
# Processing record 14 of set 3 | parfenyevo
# Processing record 15 of set 3 | attawapiskat
#  attawapiskat was not found. Skipping...
# Processing record 16 of set 3 | marfino
# Processing record 17 of set 3 | krosno odrzanskie
# Processing record 18 of set 3 | tunceli
# Processing record 19 of set 3 | carnarvon
# Processing record 20 of set 3 | victoria
# Processing record 21 of set 3 | raudeberg
# Processing record 22 of set 3 | porto novo
# Processing record 23 of set 3 | berani
# Processing record 24 of set 3 | los llanos de aridane
# Processing record 25 of set 3 | xai-xai
# Processing record 26 of set 3 | cacoal
# Processing record 27 of set 3 | hithadhoo
# Processing record 28 of set 3 | marabba
# Processing record 29 of set 3 | sao felix do xingu
# Processing record 30 of set 3 | nansio
# Processing record 31 of set 3 | rafaela
# Processing record 32 of set 3 | dabat
# Processing record 33 of set 3 | adre
# Processing record 34 of set 3 | rio gallegos
# Processing record 35 of set 3 | iqaluit
# Processing record 36 of set 3 | lagunas
# Processing record 37 of set 3 | malinovoye ozero
# Processing record 38 of set 3 | paita
# Processing record 39 of set 3 | basavakalyan
# Processing record 40 of set 3 | dingle
# Processing record 41 of set 3 | toamasina
# Processing record 42 of set 3 | ibicarai
# Processing record 43 of set 3 | longyearbyen
# Processing record 44 of set 3 | san antero
# Processing record 45 of set 3 | belz
# Processing record 46 of set 3 | sergeyevka
# Processing record 47 of set 3 | touros
# Processing record 48 of set 3 | rypefjord
# Processing record 49 of set 3 | rodrigues alves
# Processing record 50 of set 3 | tarko-sale
# Processing record 1 of set 4 | san pedro
# Processing record 2 of set 4 | awbari
# Processing record 3 of set 4 | kidal
# Processing record 4 of set 4 | sorvag
#  sorvag was not found. Skipping...
# Processing record 5 of set 4 | inirida
# Processing record 6 of set 4 | vila velha
# Processing record 7 of set 4 | jijiga
# Processing record 8 of set 4 | port-gentil
# Processing record 9 of set 4 | san carlos
# Processing record 10 of set 4 | porto santo
# Processing record 11 of set 4 | north port
# Processing record 12 of set 4 | bolobo
# Processing record 13 of set 4 | salo
# Processing record 14 of set 4 | fern creek
# Processing record 15 of set 4 | revda
# Processing record 16 of set 4 | khudumelapye
# Processing record 17 of set 4 | tulum
# Processing record 18 of set 4 | tiznit
# Processing record 19 of set 4 | dombasle-sur-meurthe
# Processing record 20 of set 4 | richards bay
# Processing record 21 of set 4 | gap
# Processing record 22 of set 4 | nalut
# Processing record 23 of set 4 | antsohihy
# Processing record 24 of set 4 | kuche
#  kuche was not found. Skipping...
# Processing record 25 of set 4 | ilulissat
# Processing record 26 of set 4 | port elizabeth
# Processing record 27 of set 4 | lumeje
# Processing record 28 of set 4 | kharp
# Processing record 29 of set 4 | uzhur
# Processing record 30 of set 4 | outjo
# Processing record 31 of set 4 | clyde river
# Processing record 32 of set 4 | maniwaki
# Processing record 33 of set 4 | bandarbeyla
# Processing record 34 of set 4 | goias
# Processing record 35 of set 4 | mednogorsk
# Processing record 36 of set 4 | blonduos
#  blonduos was not found. Skipping...
# Processing record 37 of set 4 | orodara
# Processing record 38 of set 4 | arlit
# Processing record 39 of set 4 | vallenar
# Processing record 40 of set 4 | yar-sale
# Processing record 41 of set 4 | canto do buriti
# Processing record 42 of set 4 | kinsale
# Processing record 43 of set 4 | sirjan
# Processing record 44 of set 4 | geresk
#  geresk was not found. Skipping...
# Processing record 45 of set 4 | tamale
# Processing record 46 of set 4 | bahia honda
# Processing record 47 of set 4 | jilmah
#  jilmah was not found. Skipping...
# Processing record 48 of set 4 | huarmey
# Processing record 49 of set 4 | bell ville
# Processing record 50 of set 4 | bakchar
# Processing record 1 of set 5 | royan
# Processing record 2 of set 5 | moose factory
# Processing record 3 of set 5 | oistins
# Processing record 4 of set 5 | saint anthony
# Processing record 5 of set 5 | svetlyy
# Processing record 6 of set 5 | qaqortoq
# Processing record 7 of set 5 | razdolnoye
# Processing record 8 of set 5 | beira
# Processing record 9 of set 5 | lephepe
#  lephepe was not found. Skipping...
# Processing record 10 of set 5 | san
# Processing record 11 of set 5 | canutama
# Processing record 12 of set 5 | cayenne
# Processing record 13 of set 5 | arrifes
# Processing record 14 of set 5 | murgab
# Processing record 15 of set 5 | colares
# Processing record 16 of set 5 | adrar
# Processing record 17 of set 5 | albion
# Processing record 18 of set 5 | inhambane
# Processing record 19 of set 5 | vila franca do campo
# Processing record 20 of set 5 | saint-pierre
# Processing record 21 of set 5 | benguela
# Processing record 22 of set 5 | natal
# Processing record 23 of set 5 | boa vista
# Processing record 24 of set 5 | the valley
# Processing record 25 of set 5 | muisne
# Processing record 26 of set 5 | mangan
# Processing record 27 of set 5 | nargana
# Processing record 28 of set 5 | paamiut
# Processing record 29 of set 5 | bud
# Processing record 30 of set 5 | louisbourg
#  louisbourg was not found. Skipping...
# Processing record 31 of set 5 | polovinnoye
# Processing record 32 of set 5 | lusambo
# Processing record 33 of set 5 | tasiilaq
# Processing record 34 of set 5 | mogadishu
# Processing record 35 of set 5 | puerto quijarro
# Processing record 36 of set 5 | bohdan
# Processing record 37 of set 5 | lebu
# Processing record 38 of set 5 | barentu
# Processing record 39 of set 5 | kutum
# Processing record 40 of set 5 | firozpur
# Processing record 41 of set 5 | sinnamary
# Processing record 42 of set 5 | niamey
# Processing record 43 of set 5 | conneaut
# Processing record 44 of set 5 | tripoli
# Processing record 45 of set 5 | salalah
# Processing record 46 of set 5 | agirish
# Processing record 47 of set 5 | taltal
# Processing record 48 of set 5 | borama
#  borama was not found. Skipping...
# Processing record 49 of set 5 | ostersund
# Processing record 50 of set 5 | saint george
# Processing record 1 of set 6 | gnjilane
# Processing record 2 of set 6 | opuwo
# Processing record 3 of set 6 | aswan
# Processing record 4 of set 6 | andevoranto
#  andevoranto was not found. Skipping...
# Processing record 5 of set 6 | quatre cocos
# Processing record 6 of set 6 | sao filipe
# Processing record 7 of set 6 | korycany
# Processing record 8 of set 6 | puerto el triunfo
# Processing record 9 of set 6 | sharlyk
# Processing record 10 of set 6 | padang
# Processing record 11 of set 6 | bengkulu
# Processing record 12 of set 6 | fuengirola
# Processing record 13 of set 6 | briancon
# Processing record 14 of set 6 | buena vista
# Processing record 15 of set 6 | saint stephen
# Processing record 16 of set 6 | mahon
# Processing record 17 of set 6 | chake chake
# Processing record 18 of set 6 | velikodvorskiy
# Processing record 19 of set 6 | abapo
# Processing record 20 of set 6 | andenes
# Processing record 21 of set 6 | muromtsevo
# Processing record 22 of set 6 | nuuk
# Processing record 23 of set 6 | yarada
# Processing record 24 of set 6 | skalistyy
#  skalistyy was not found. Skipping...
# Processing record 25 of set 6 | funtua
# Processing record 26 of set 6 | senneterre
# Processing record 27 of set 6 | saint-joseph
# Processing record 28 of set 6 | umea
# Processing record 29 of set 6 | nara
# Processing record 30 of set 6 | saint-augustin
# Processing record 31 of set 6 | zhezkazgan
# Processing record 32 of set 6 | beyneu
# Processing record 33 of set 6 | jacqueville
# Processing record 34 of set 6 | hambantota
# Processing record 35 of set 6 | grootfontein
# Processing record 36 of set 6 | dzhusaly
#  dzhusaly was not found. Skipping...
# Processing record 37 of set 6 | tocopilla
# Processing record 38 of set 6 | mocambique
#  mocambique was not found. Skipping...
# Processing record 39 of set 6 | pathanamthitta
# Processing record 40 of set 6 | chingirlau
# Processing record 41 of set 6 | saint-pacome
#  saint-pacome was not found. Skipping...
# Processing record 42 of set 6 | luanda
# Processing record 43 of set 6 | poshekhonye
# Processing record 44 of set 6 | la asuncion
# Processing record 45 of set 6 | puerto ayora
# Processing record 46 of set 6 | ocala
# Processing record 47 of set 6 | pitimbu
# Processing record 48 of set 6 | ambilobe
# Processing record 49 of set 6 | guanica
# Processing record 50 of set 6 | alice town
# Processing record 1 of set 7 | rocha
# Processing record 2 of set 7 | zhanatas
#  zhanatas was not found. Skipping...
# Processing record 3 of set 7 | ciudad bolivar
# Processing record 4 of set 7 | krasnoselkup
# Processing record 5 of set 7 | ostrovnoy
# Processing record 6 of set 7 | caravelas
# Processing record 7 of set 7 | shelburne
# Processing record 8 of set 7 | kemijarvi
# Processing record 9 of set 7 | malko tarnovo
# Processing record 10 of set 7 | umm kaddadah
# Processing record 11 of set 7 | trinidad
# Processing record 12 of set 7 | iquitos
# Processing record 13 of set 7 | viedma
# Processing record 14 of set 7 | klaksvik
# Processing record 15 of set 7 | korla
# Processing record 16 of set 7 | kushmurun
# Processing record 17 of set 7 | cheremukhovo
# Processing record 18 of set 7 | bathsheba
# Processing record 19 of set 7 | aktash
# Processing record 20 of set 7 | vestmannaeyjar
# Processing record 21 of set 7 | muscat
# Processing record 22 of set 7 | tabuk
# Processing record 23 of set 7 | gidole
# Processing record 24 of set 7 | kourou
# Processing record 25 of set 7 | muros
# Processing record 26 of set 7 | grindavik
# Processing record 27 of set 7 | berlevag
# Processing record 28 of set 7 | skole
# Processing record 29 of set 7 | bara
# Processing record 30 of set 7 | matagami
# Processing record 31 of set 7 | trelew
# Processing record 32 of set 7 | ishim
# Processing record 33 of set 7 | nouadhibou
# Processing record 34 of set 7 | abu samrah
# Processing record 35 of set 7 | wageningen
# Processing record 36 of set 7 | liniere
#  liniere was not found. Skipping...
# Processing record 37 of set 7 | abu kamal
# Processing record 38 of set 7 | itarema
# Processing record 39 of set 7 | zychlin
# Processing record 40 of set 7 | brae
# Processing record 41 of set 7 | saint-georges
# Processing record 42 of set 7 | coruripe
# Processing record 43 of set 7 | porbandar
# Processing record 44 of set 7 | alta floresta
# Processing record 45 of set 7 | geraldton
# Processing record 46 of set 7 | sicuani
# Processing record 47 of set 7 | zabid
# Processing record 48 of set 7 | kharan
# Processing record 49 of set 7 | hobyo
# Processing record 50 of set 7 | pskov
# Processing record 1 of set 8 | meulaboh
# Processing record 2 of set 8 | humenne
# Processing record 3 of set 8 | qandala
# Processing record 4 of set 8 | lima
# Processing record 5 of set 8 | lieksa
# Processing record 6 of set 8 | gornopravdinsk
# Processing record 7 of set 8 | sayyan
# Processing record 8 of set 8 | canchungo
# Processing record 9 of set 8 | oudtshoorn
# Processing record 10 of set 8 | zaqatala
# Processing record 11 of set 8 | salinopolis
# Processing record 12 of set 8 | longlac
#  longlac was not found. Skipping...
# Processing record 13 of set 8 | doka
# Processing record 14 of set 8 | kasrawad
# Processing record 15 of set 8 | sortland
# Processing record 16 of set 8 | abonnema
# Processing record 17 of set 8 | quelimane
# Processing record 18 of set 8 | pinheiro machado
# Processing record 19 of set 8 | kollumerland
#  kollumerland was not found. Skipping...
# Processing record 20 of set 8 | nouakchott
# Processing record 21 of set 8 | pisco
# Processing record 22 of set 8 | visby
# Processing record 23 of set 8 | honningsvag
# Processing record 24 of set 8 | tyumentsevo
# Processing record 25 of set 8 | koster
# Processing record 26 of set 8 | kanye
# Processing record 27 of set 8 | kabinda
# Processing record 28 of set 8 | butzow
# Processing record 29 of set 8 | potgietersrus
#  potgietersrus was not found. Skipping...
# Processing record 30 of set 8 | bogandinskiy
# Processing record 31 of set 8 | talnakh
# Processing record 32 of set 8 | sao domingos do prata
# Processing record 33 of set 8 | marsa matruh
# Processing record 34 of set 8 | sept-iles
# Processing record 35 of set 8 | kardla
# Processing record 36 of set 8 | fort myers beach
# Processing record 37 of set 8 | guder
# Processing record 38 of set 8 | makinsk
# Processing record 39 of set 8 | behbahan
# Processing record 40 of set 8 | ibicui
# Processing record 41 of set 8 | gamba
# Processing record 42 of set 8 | new kensington
# Processing record 43 of set 8 | tarudant
#  tarudant was not found. Skipping...
# Processing record 44 of set 8 | ambovombe
# Processing record 45 of set 8 | katav-ivanovsk
# Processing record 46 of set 8 | marsh harbour
# Processing record 47 of set 8 | poykovskiy
# Processing record 48 of set 8 | vologda
# Processing record 49 of set 8 | santiago del estero
# Processing record 50 of set 8 | ayna
# Processing record 1 of set 9 | sassandra
# Processing record 2 of set 9 | najran
# Processing record 3 of set 9 | bulawayo
# Processing record 4 of set 9 | acarau
# Processing record 5 of set 9 | constantine
# Processing record 6 of set 9 | silifke
# Processing record 7 of set 9 | meiganga
# Processing record 8 of set 9 | coulihaut
#  coulihaut was not found. Skipping...
# Processing record 9 of set 9 | maloshuyka
#  maloshuyka was not found. Skipping...
# Processing record 10 of set 9 | kamenka
# Processing record 11 of set 9 | ashington
# Processing record 12 of set 9 | evinayong
# Processing record 13 of set 9 | riyadh
# Processing record 14 of set 9 | plouzane
# Processing record 15 of set 9 | hadrut
# Processing record 16 of set 9 | new glasgow
# Processing record 17 of set 9 | shchelyayur
#  shchelyayur was not found. Skipping...
# Processing record 18 of set 9 | virginia beach
# Processing record 19 of set 9 | filadelfia
# Processing record 20 of set 9 | uspenka
# Processing record 21 of set 9 | kargil
# Processing record 22 of set 9 | pangnirtung
# Processing record 23 of set 9 | mungwi
# Processing record 24 of set 9 | amapala
# Processing record 25 of set 9 | nicoya
# Processing record 26 of set 9 | chalmette
# Processing record 27 of set 9 | maceio
# Processing record 28 of set 9 | winchester
# Processing record 29 of set 9 | kabalo
# Processing record 30 of set 9 | mitsamiouli
# Processing record 31 of set 9 | sanaur
# Processing record 32 of set 9 | mouzakion
#  mouzakion was not found. Skipping...
# Processing record 33 of set 9 | omboue
# Processing record 34 of set 9 | port-de-paix
#  port-de-paix was not found. Skipping...
# Processing record 35 of set 9 | asayita
#  asayita was not found. Skipping...
# Processing record 36 of set 9 | aktas
# Processing record 37 of set 9 | sechura
# Processing record 38 of set 9 | dedovichi
# Processing record 39 of set 9 | general roca
# Processing record 40 of set 9 | igrim
# Processing record 41 of set 9 | togur
# Processing record 42 of set 9 | kinrooi
# Processing record 43 of set 9 | brewster
# Processing record 44 of set 9 | kochinda
# Processing record 45 of set 9 | bathurst
# Processing record 46 of set 9 | turukhansk
# Processing record 47 of set 9 | oskemen
# Processing record 48 of set 9 | carutapera
# Processing record 49 of set 9 | mongo
# Processing record 50 of set 9 | lagos
# Processing record 1 of set 10 | la rioja
# Processing record 2 of set 10 | soria
# Processing record 3 of set 10 | sambava
# Processing record 4 of set 10 | tarabuco
# Processing record 5 of set 10 | sohag
# Processing record 6 of set 10 | kizilskoye
# Processing record 7 of set 10 | kugulta
# Processing record 8 of set 10 | dalvik
# Processing record 9 of set 10 | karasburg
# Processing record 10 of set 10 | paulo afonso
# Processing record 11 of set 10 | burriana
# Processing record 12 of set 10 | pittsfield
# Processing record 13 of set 10 | hualmay
# Processing record 14 of set 10 | templin
# Processing record 15 of set 10 | usoke
# Processing record 16 of set 10 | saint-agapit
# Processing record 17 of set 10 | puerto leguizamo
# Processing record 18 of set 10 | salekhard
# Processing record 19 of set 10 | aksarka
# Processing record 20 of set 10 | kochevo
# Processing record 21 of set 10 | galbshtadt
# Processing record 22 of set 10 | vardo
# Processing record 23 of set 10 | puerto narino
# Processing record 24 of set 10 | luau
# Processing record 25 of set 10 | mecca
# Processing record 26 of set 10 | lamu
# Processing record 27 of set 10 | tenali
# Processing record 28 of set 10 | aleksandrov gay
# Processing record 29 of set 10 | morondava
# Processing record 30 of set 10 | abu jubayhah
#  abu jubayhah was not found. Skipping...
# Processing record 31 of set 10 | kamina
# Processing record 32 of set 10 | qazvin
# Processing record 33 of set 10 | olafsvik
# Processing record 34 of set 10 | wamba
# Processing record 35 of set 10 | vestmanna
# Processing record 36 of set 10 | harsud
# Processing record 37 of set 10 | maimon
#  maimon was not found. Skipping...
# Processing record 38 of set 10 | queimadas
# Processing record 39 of set 10 | bridlington
# Processing record 40 of set 10 | dehloran
# Processing record 41 of set 10 | springbok
# Processing record 42 of set 10 | takoradi
# Processing record 43 of set 10 | polyarnyy
# Processing record 44 of set 10 | rolante
# Processing record 45 of set 10 | reconquista
# Processing record 46 of set 10 | kotlas
# Processing record 47 of set 10 | kytmanovo
# Processing record 48 of set 10 | bonavista
# Processing record 49 of set 10 | melbu
# Processing record 50 of set 10 | mende
# Processing record 1 of set 11 | boende
# Processing record 2 of set 11 | adeje
# Processing record 3 of set 11 | savannah bight
# Processing record 4 of set 11 | strezhevoy
# Processing record 5 of set 11 | kerewan
# Processing record 6 of set 11 | filingue
# Processing record 7 of set 11 | wajid
# Processing record 8 of set 11 | camana
# Processing record 9 of set 11 | zaysan
# Processing record 10 of set 11 | coquimbo
# Processing record 11 of set 11 | pell city
# Processing record 12 of set 11 | bossembele
#  bossembele was not found. Skipping...
# Processing record 13 of set 11 | bardiyah
# Processing record 14 of set 11 | joshimath
# Processing record 15 of set 11 | matca
# Processing record 16 of set 11 | valente
# Processing record 17 of set 11 | jalu
# Processing record 18 of set 11 | paradwip
#  paradwip was not found. Skipping...
# Processing record 19 of set 11 | megion
# Processing record 20 of set 11 | barawe
#  barawe was not found. Skipping...
# Processing record 21 of set 11 | birjand
# Processing record 22 of set 11 | arucas
# Processing record 23 of set 11 | port-cartier
# Processing record 24 of set 11 | altoona
# Processing record 25 of set 11 | tysmenychany
# Processing record 26 of set 11 | barsi
# Processing record 27 of set 11 | yanam
# Processing record 28 of set 11 | miastko
# Processing record 29 of set 11 | cumaribo
#  cumaribo was not found. Skipping...
# Processing record 30 of set 11 | sioux lookout
# Processing record 31 of set 11 | qasigiannguit
# Processing record 32 of set 11 | margate
# Processing record 33 of set 11 | zilair
# Processing record 34 of set 11 | dianopolis
#  dianopolis was not found. Skipping...
# Processing record 35 of set 11 | campos novos
# Processing record 36 of set 11 | shenkursk
# Processing record 37 of set 11 | sur
# Processing record 38 of set 11 | saint-louis
# Processing record 39 of set 11 | kasongo-lunda
# Processing record 40 of set 11 | gornyak
# Processing record 41 of set 11 | ugoofaaru
# Processing record 42 of set 11 | fredericton
# Processing record 43 of set 11 | cockburn town
# Processing record 44 of set 11 | casma
# Processing record 45 of set 11 | karia
# Processing record 46 of set 11 | uddevalla
# Processing record 47 of set 11 | mahajanga
# Processing record 48 of set 11 | mount darwin
# Processing record 49 of set 11 | bur gabo
#  bur gabo was not found. Skipping...
# Processing record 50 of set 11 | maniitsoq
# Processing record 1 of set 12 | mayor pablo lagerenza
# Processing record 2 of set 12 | kenscoff
# Processing record 3 of set 12 | santa maria
# Processing record 4 of set 12 | albany
# Processing record 5 of set 12 | sayan
# Processing record 6 of set 12 | deder
# Processing record 7 of set 12 | aconibe
# Processing record 8 of set 12 | wajir
# Processing record 9 of set 12 | waw
# Processing record 10 of set 12 | havre-saint-pierre
# Processing record 11 of set 12 | rajpipla
# Processing record 12 of set 12 | pedernales
# Processing record 13 of set 12 | kalmunai
# Processing record 14 of set 12 | escanaba
# Processing record 15 of set 12 | istria
# Processing record 16 of set 12 | rudbar
# Processing record 17 of set 12 | inverness
# Processing record 18 of set 12 | punta de piedra
# Processing record 19 of set 12 | develi
# Processing record 20 of set 12 | velizh
# Processing record 21 of set 12 | tyukhtet
# Processing record 22 of set 12 | ballina
# Processing record 23 of set 12 | waddan
# Processing record 24 of set 12 | shieli
# Processing record 25 of set 12 | sumbe
# Processing record 26 of set 12 | uzumlu
#  uzumlu was not found. Skipping...
# Processing record 27 of set 12 | praia da vitoria
# Processing record 28 of set 12 | tessalit
# Processing record 29 of set 12 | san lorenzo
# Processing record 30 of set 12 | coihaique
# Processing record 31 of set 12 | soyo
# Processing record 32 of set 12 | karasjok
# Processing record 33 of set 12 | sisimiut
# Processing record 34 of set 12 | kulhudhuffushi
# Processing record 35 of set 12 | nadym
# Processing record 36 of set 12 | la seyne-sur-mer
# Processing record 37 of set 12 | barranca
# Processing record 38 of set 12 | plettenberg bay
# Processing record 39 of set 12 | fomboni
# Processing record 40 of set 12 | fussen
# Processing record 41 of set 12 | katima mulilo
# Processing record 42 of set 12 | odweyne
# Processing record 43 of set 12 | luena
# Processing record 44 of set 12 | ikalamavony
# Processing record 45 of set 12 | asyut
# Processing record 46 of set 12 | kavaratti
# Processing record 47 of set 12 | birnin kebbi
# Processing record 48 of set 12 | graham
# Processing record 49 of set 12 | lena
# Processing record 50 of set 12 | naral
#  naral was not found. Skipping...
# Processing record 1 of set 13 | gambela
# Processing record 2 of set 13 | cabedelo
# Processing record 3 of set 13 | dubenskiy
#  dubenskiy was not found. Skipping...
# Processing record 4 of set 13 | skibbereen
# Processing record 5 of set 13 | serdobsk
# Processing record 6 of set 13 | totskoye
# Processing record 7 of set 13 | hamilton
# Processing record 8 of set 13 | shubarshi
# Processing record 9 of set 13 | paducah
# Processing record 10 of set 13 | aanekoski
# Processing record 11 of set 13 | thinadhoo
# Processing record 12 of set 13 | yangambi
# Processing record 13 of set 13 | mayumba
# Processing record 14 of set 13 | cudahy
# Processing record 15 of set 13 | hof
# Processing record 16 of set 13 | bialystok
# Processing record 17 of set 13 | kolaras
# Processing record 18 of set 13 | sao miguel do araguaia
# Processing record 19 of set 13 | ndiekro
#  ndiekro was not found. Skipping...
# Processing record 20 of set 13 | parintins
# Processing record 21 of set 13 | semnan
# Processing record 22 of set 13 | marawi
# Processing record 23 of set 13 | saint-michel-des-saints
# Processing record 24 of set 13 | sao jose da coroa grande
# Processing record 25 of set 13 | mogochin
#  mogochin was not found. Skipping...
# Processing record 26 of set 13 | butterworth
# Processing record 27 of set 13 | grand gaube
# Processing record 28 of set 13 | tambopata
# Processing record 29 of set 13 | ercis
# Processing record 30 of set 13 | mbandaka
# Processing record 31 of set 13 | kazalinsk
#  kazalinsk was not found. Skipping...
# Processing record 32 of set 13 | jaque
# Processing record 33 of set 13 | agstafa
#  agstafa was not found. Skipping...
# Processing record 34 of set 13 | somoto
# Processing record 35 of set 13 | koygorodok
# Processing record 36 of set 13 | abu dhabi
# Processing record 37 of set 13 | rawah
# Processing record 38 of set 13 | methala
# Processing record 39 of set 13 | radovis
# Processing record 40 of set 13 | melioratorov
# Processing record 41 of set 13 | ubinskoye
# Processing record 42 of set 13 | atar
# Processing record 43 of set 13 | cerrito
# Processing record 44 of set 13 | samana
# Processing record 45 of set 13 | formoso do araguaia
#  formoso do araguaia was not found. Skipping...
# Processing record 46 of set 13 | belmonte
# Processing record 47 of set 13 | araouane
# Processing record 48 of set 13 | ulagan
# Processing record 49 of set 13 | sakakah
# Processing record 50 of set 13 | wundanyi
# Processing record 1 of set 14 | copiapo
# Processing record 2 of set 14 | umm lajj
# Processing record 3 of set 14 | imbituba
# Processing record 4 of set 14 | chapais
# Processing record 5 of set 14 | surgut
# Processing record 6 of set 14 | qobustan
# Processing record 7 of set 14 | chernoyerkovskaya
# Processing record 8 of set 14 | karakendzha
#  karakendzha was not found. Skipping...
# Processing record 9 of set 14 | cap-aux-meules
# Processing record 10 of set 14 | mikumi
# Processing record 11 of set 14 | bereda
# Processing record 12 of set 14 | inderborskiy
#  inderborskiy was not found. Skipping...
# Processing record 13 of set 14 | lokoja
# Processing record 14 of set 14 | indiana
# Processing record 15 of set 14 | port hawkesbury
# Processing record 16 of set 14 | caraballeda
# Processing record 17 of set 14 | veraval
# Processing record 18 of set 14 | almeirim
# Processing record 19 of set 14 | mpika
# Processing record 20 of set 14 | taybad
# Processing record 21 of set 14 | matay
# Processing record 22 of set 14 | bongandanga
# Processing record 23 of set 14 | pimentel
# Processing record 24 of set 14 | provins
# Processing record 25 of set 14 | karkaralinsk
#  karkaralinsk was not found. Skipping...
# Processing record 26 of set 14 | ravar
# Processing record 27 of set 14 | khanskaya
# Processing record 28 of set 14 | putina
# Processing record 29 of set 14 | monteagudo
# Processing record 30 of set 14 | garowe
# Processing record 31 of set 14 | visnes
# Processing record 32 of set 14 | mochudi
# Processing record 33 of set 14 | miraflores
# Processing record 34 of set 14 | qovlar
# Processing record 35 of set 14 | iskateley
# Processing record 36 of set 14 | serenje
# Processing record 37 of set 14 | baryshivka
# Processing record 38 of set 14 | duz
#  duz was not found. Skipping...
# Processing record 39 of set 14 | loiza
# Processing record 40 of set 14 | barcelos
# Processing record 41 of set 14 | dornoch
# Processing record 42 of set 14 | toliary
#  toliary was not found. Skipping...
# Processing record 43 of set 14 | alekseyevka
# Processing record 44 of set 14 | ngaoundere
# Processing record 45 of set 14 | caconda
# Processing record 46 of set 14 | abeche
# Processing record 47 of set 14 | mamallapuram
# Processing record 48 of set 14 | curico
# Processing record 49 of set 14 | mahuva
# Processing record 50 of set 14 | peto
# Processing record 1 of set 15 | lexington-fayette
# Processing record 2 of set 15 | san andres
# Processing record 3 of set 15 | chabahar
# Processing record 4 of set 15 | kashi
# Processing record 5 of set 15 | pital
# Processing record 6 of set 15 | bonthe
# Processing record 7 of set 15 | murmashi
# Processing record 8 of set 15 | oktyabrskiy
# Processing record 9 of set 15 | gwanda
# Processing record 10 of set 15 | ilhabela
# Processing record 11 of set 15 | kardamaina
# Processing record 12 of set 15 | sistranda
# Processing record 13 of set 15 | presidencia roque saenz pena
# Processing record 14 of set 15 | tunduru
#  tunduru was not found. Skipping...
# Processing record 15 of set 15 | kizema
# Processing record 16 of set 15 | syracuse
# Processing record 17 of set 15 | antofagasta
# Processing record 18 of set 15 | sabha
# Processing record 19 of set 15 | panjwin
#  panjwin was not found. Skipping...
# Processing record 20 of set 15 | sabibah
#  sabibah was not found. Skipping...
# Processing record 21 of set 15 | probistip
# Processing record 22 of set 15 | casablanca
# Processing record 23 of set 15 | urengoy
# Processing record 24 of set 15 | diamantino
# Processing record 25 of set 15 | acari
# Processing record 26 of set 15 | nioro
# Processing record 27 of set 15 | bubaque
# Processing record 28 of set 15 | goderich
# Processing record 29 of set 15 | ondangwa
# Processing record 30 of set 15 | saint-francois
# Processing record 31 of set 15 | mtwara
# Processing record 32 of set 15 | skjervoy
# Processing record 33 of set 15 | bargal
#  bargal was not found. Skipping...
# Processing record 34 of set 15 | bhanpura
# Processing record 35 of set 15 | kashan
# Processing record 36 of set 15 | mercedes
# Processing record 37 of set 15 | karaul
#  karaul was not found. Skipping...
# Processing record 38 of set 15 | kathmandu
# Processing record 39 of set 15 | sibenik
# Processing record 40 of set 15 | la roda
# Processing record 41 of set 15 | marystown
# Processing record 42 of set 15 | truro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Muskegon',
#   'Country': 'US',
#   'Lat': 43.3,
#   'Lng': -86.1334,
#   'Max Temp': 27,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 21.99,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Current Description': 'light snow'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 59,
#   'Humidity': 41,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 60.8,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Kuryk',
#   'Country': 'KZ',
#   'Lat': 43.2,
#   'Lng': 51.65,
#   'Max Temp': 28.76,
#   'Humidity': 85,
#   'Cloudiness': 58,
#   'Wind Speed': 17.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'West Bay',
#   'Country': 'KY',
#   'Lat': 19.3667,
#   'Lng': -81.4167,
#   'Max Temp': 79,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Colombia',
#   'Country': 'CO',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Valdivia',
#   'Country': 'CL',
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 89.6,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 41,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pasni',
#   'Country': 'PK',
#   'Lat': 25.2631,
#   'Lng': 63.471,
#   'Max Temp': 69.33,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Camocim',
#   'Country': 'BR',
#   'Lat': -2.9022,
#   'Lng': -40.8411,
#   'Max Temp': 80.53,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Current Description': 'moderate rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 1.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Dolores',
#   'Country': 'AR',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 89.62,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 16.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 69.01,
#   'Humidity': 81,
#   'Cloudiness': 83,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cambridge',
#   'Country': 'CA',
#   'Lat': 43.3601,
#   'Lng': -80.3127,
#   'Max Temp': 23,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Current Description': 'light snow'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 61,
#   'Humidity': 68,
#   'Cloudiness': 33,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alto Araguaia',
#   'Country': 'BR',
#   'Lat': -17.3147,
#   'Lng': -53.2153,
#   'Max Temp': 83.64,
#   'Humidity': 57,
#   'Cloudiness': 66,
#   'Wind Speed': 4.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 89.6,
#   'Humidity': 27,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Eyl',
#   'Country': 'SO',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 76.14,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 18.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 87.69,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 18.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Vrede',
#   'Country': 'ZA',
#   'Lat': -27.4257,
#   'Lng': 29.1659,
#   'Max Temp': 61.84,
#   'Humidity': 79,
#   'Cloudiness': 22,
#   'Wind Speed': 6.89,
#   'Current Description': 'few clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -7.73,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tromso',
#   'Country': 'NO',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp': 21.2,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tandil',
#   'Country': 'AR',
#   'Lat': -37.3217,
#   'Lng': -59.1332,
#   'Max Temp': 95,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 67.84,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mao',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 75.02,
#   'Humidity': 73,
#   'Cloudiness': 77,
#   'Wind Speed': 12.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Oksfjord',
#   'Country': 'NO',
#   'Lat': 70.2396,
#   'Lng': 22.3479,
#   'Max Temp': 23,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 35.6,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 30,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 86,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Crestview',
#   'Country': 'US',
#   'Lat': 30.7621,
#   'Lng': -86.5705,
#   'Max Temp': 71.01,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 76.19,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 12.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Sebina',
#   'Country': 'BW',
#   'Lat': -20.8667,
#   'Lng': 27.25,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Zemio',
#   'Country': 'CF',
#   'Lat': 5.0314,
#   'Lng': 25.1361,
#   'Max Temp': 72.64,
#   'Humidity': 27,
#   'Cloudiness': 88,
#   'Wind Speed': 4.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Madryn',
#   'Country': 'AR',
#   'Lat': -42.7692,
#   'Lng': -65.0385,
#   'Max Temp': 86.02,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 20.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Gwadar',
#   'Country': 'PK',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 69.19,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Hun',
#   'Country': 'LY',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 51.8,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Current Description': 'clear sky'},
#  {'City': 'San Luis',
#   'Country': 'AR',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 91.26,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 6.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaura Namoda',
#   'Country': 'NG',
#   'Lat': 12.5898,
#   'Lng': 6.5779,
#   'Max Temp': 70.47,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 10.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Zitsa',
#   'Country': 'GR',
#   'Lat': 39.6943,
#   'Lng': 20.6372,
#   'Max Temp': 39.2,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 46.2,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 69.01,
#   'Humidity': 84,
#   'Cloudiness': 55,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 29.8,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 79.43,
#   'Humidity': 79,
#   'Cloudiness': 22,
#   'Wind Speed': 4.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Krasnoarmeysk',
#   'Country': 'RU',
#   'Lat': 51.0239,
#   'Lng': 45.6969,
#   'Max Temp': -8.39,
#   'Humidity': 91,
#   'Cloudiness': 17,
#   'Wind Speed': 9.46,
#   'Current Description': 'few clouds'},
#  {'City': 'Beboto',
#   'Country': 'TD',
#   'Lat': 8.2668,
#   'Lng': 16.939,
#   'Max Temp': 77.63,
#   'Humidity': 18,
#   'Cloudiness': 91,
#   'Wind Speed': 4.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 26.74,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gaoual',
#   'Country': 'GN',
#   'Lat': 11.75,
#   'Lng': -13.2,
#   'Max Temp': 82.4,
#   'Humidity': 14,
#   'Cloudiness': 37,
#   'Wind Speed': 3.56,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 61.36,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 22.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 72.81,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 10.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'moderate rain'},
#  {'City': 'Conceicao Do Araguaia',
#   'Country': 'BR',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 79.61,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Current Description': 'moderate rain'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 39.2,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 27.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ati',
#   'Country': 'TD',
#   'Lat': 13.2154,
#   'Lng': 18.3353,
#   'Max Temp': 70.11,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 14.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 62.01,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 53.01,
#   'Humidity': 100,
#   'Cloudiness': 1,
#   'Wind Speed': 8.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Salinas',
#   'Country': 'US',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 66,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Placido De Castro',
#   'Country': 'BR',
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp': 85.91,
#   'Humidity': 52,
#   'Cloudiness': 94,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Voskresenskoye',
#   'Country': 'RU',
#   'Lat': 56.8381,
#   'Lng': 45.4317,
#   'Max Temp': 10.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 28,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 28.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yenagoa',
#   'Country': 'NG',
#   'Lat': 4.9247,
#   'Lng': 6.2642,
#   'Max Temp': 79.02,
#   'Humidity': 82,
#   'Cloudiness': 7,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Andra',
#   'Country': 'RU',
#   'Lat': 62.5147,
#   'Lng': 65.8878,
#   'Max Temp': -2.61,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahibadhoo',
#   'Country': 'MV',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 81.66,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 9.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 69.04,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Current Description': 'moderate rain'},
#  {'City': 'Castel Volturno',
#   'Country': 'IT',
#   'Lat': 41.0149,
#   'Lng': 13.9462,
#   'Max Temp': 57,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 15.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 50.85,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Edd',
#   'Country': 'ER',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 75.7,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 30.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'light snow'},
#  {'City': 'Amapa',
#   'Country': 'BR',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 72.36,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Nortelandia',
#   'Country': 'BR',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Max Temp': 85.21,
#   'Humidity': 73,
#   'Cloudiness': 93,
#   'Wind Speed': 3.24,
#   'Current Description': 'moderate rain'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 69.87,
#   'Humidity': 20,
#   'Cloudiness': 72,
#   'Wind Speed': 11.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 69.12,
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 9.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 31.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Current Description': 'light snow'},
#  {'City': 'Saint-Leu',
#   'Country': 'RE',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'moderate rain'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 86,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Havelock',
#   'Country': 'US',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 57.2,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Hadejia',
#   'Country': 'NG',
#   'Lat': 12.4498,
#   'Lng': 10.0444,
#   'Max Temp': 69.91,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 13.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 32.13,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 27.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 17,
#   'Wind Speed': 4,
#   'Current Description': 'few clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Turayf',
#   'Country': 'SA',
#   'Lat': 31.6725,
#   'Lng': 38.6637,
#   'Max Temp': 35.6,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 7.94,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 81,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 70.9,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 12.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Braniewo',
#   'Country': 'PL',
#   'Lat': 54.3797,
#   'Lng': 19.8196,
#   'Max Temp': 36.3,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Parfenyevo',
#   'Country': 'RU',
#   'Lat': 58.484,
#   'Lng': 43.4088,
#   'Max Temp': 4.69,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 5.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marfino',
#   'Country': 'RU',
#   'Lat': 55.7028,
#   'Lng': 37.3822,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Krosno Odrzanskie',
#   'Country': 'PL',
#   'Lat': 52.0549,
#   'Lng': 15.0988,
#   'Max Temp': 42.01,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Tunceli',
#   'Country': 'TR',
#   'Lat': 39.1083,
#   'Lng': 39.5471,
#   'Max Temp': 21.2,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 64.99,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Raudeberg',
#   'Country': 'NO',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 39.99,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 12.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 82.4,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Berani',
#   'Country': 'PK',
#   'Lat': 25.785,
#   'Lng': 68.8069,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.35,
#   'Current Description': 'smoke'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Xai-Xai',
#   'Country': 'MZ',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 77.79,
#   'Humidity': 79,
#   'Cloudiness': 41,
#   'Wind Speed': 10.89,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cacoal',
#   'Country': 'BR',
#   'Lat': -11.4386,
#   'Lng': -61.4472,
#   'Max Temp': 72.93,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.84,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 10.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marabba',
#   'Country': 'SD',
#   'Lat': 12.35,
#   'Lng': 32.1833,
#   'Max Temp': 70.72,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 16.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 72.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Current Description': 'light rain'},
#  {'City': 'Nansio',
#   'Country': 'TZ',
#   'Lat': -2.1333,
#   'Lng': 33.05,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rafaela',
#   'Country': 'AR',
#   'Lat': -31.2503,
#   'Lng': -61.4867,
#   'Max Temp': 90,
#   'Humidity': 17,
#   'Cloudiness': 12,
#   'Wind Speed': 8.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Dabat',
#   'Country': 'ET',
#   'Lat': 12.9842,
#   'Lng': 37.765,
#   'Max Temp': 50.14,
#   'Humidity': 56,
#   'Cloudiness': 3,
#   'Wind Speed': 4.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Adre',
#   'Country': 'TD',
#   'Lat': 13.4667,
#   'Lng': 22.2,
#   'Max Temp': 62.94,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 19.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 66.2,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 5,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Current Description': 'snow'},
#  {'City': 'Lagunas',
#   'Country': 'PE',
#   'Lat': -5.2269,
#   'Lng': -75.6753,
#   'Max Temp': 73.45,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.51,
#   'Current Description': 'light rain'},
#  {'City': 'Malinovoye Ozero',
#   'Country': 'RU',
#   'Lat': 51.6753,
#   'Lng': 79.7825,
#   'Max Temp': 22.53,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Paita',
#   'Country': 'PE',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 82.4,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Basavakalyan',
#   'Country': 'IN',
#   'Lat': 17.8667,
#   'Lng': 76.95,
#   'Max Temp': 69.67,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 0.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 74.91,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 2.51,
#   'Current Description': 'light rain'},
#  {'City': 'Toamasina',
#   'Country': 'MG',
#   'Lat': -18.1667,
#   'Lng': 49.3833,
#   'Max Temp': 82.4,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Current Description': 'light rain'},
#  {'City': 'Ibicarai',
#   'Country': 'BR',
#   'Lat': -14.865,
#   'Lng': -39.5875,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 15.8,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Current Description': 'few clouds'},
#  {'City': 'San Antero',
#   'Country': 'CO',
#   'Lat': 9.3741,
#   'Lng': -75.7589,
#   'Max Temp': 86.58,
#   'Humidity': 57,
#   'Cloudiness': 42,
#   'Wind Speed': 10.38,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Belz',
#   'Country': 'FR',
#   'Lat': 47.6751,
#   'Lng': -3.168,
#   'Max Temp': 52,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 31.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sergeyevka',
#   'Country': 'KZ',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': -2.88,
#   'Humidity': 91,
#   'Cloudiness': 80,
#   'Wind Speed': 14.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rypefjord',
#   'Country': 'NO',
#   'Lat': 70.6333,
#   'Lng': 23.6667,
#   'Max Temp': 17.6,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Rodrigues Alves',
#   'Country': 'BR',
#   'Lat': -7.738,
#   'Lng': -72.6509,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': -29.72,
#   'Humidity': 85,
#   'Cloudiness': 11,
#   'Wind Speed': 5.7,
#   'Current Description': 'few clouds'},
#  {'City': 'San Pedro',
#   'Country': 'PH',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.14,
#   'Current Description': 'moderate rain'},
#  {'City': 'Awbari',
#   'Country': 'LY',
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp': 48.22,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 7.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Kidal',
#   'Country': 'ML',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 66.65,
#   'Humidity': 22,
#   'Cloudiness': 73,
#   'Wind Speed': 11.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Inirida',
#   'Country': 'CO',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 83.57,
#   'Humidity': 79,
#   'Cloudiness': 83,
#   'Wind Speed': 1.99,
#   'Current Description': 'moderate rain'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jijiga',
#   'Country': 'ET',
#   'Lat': 9.35,
#   'Lng': 42.8,
#   'Max Temp': 60.89,
#   'Humidity': 33,
#   'Cloudiness': 4,
#   'Wind Speed': 6.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'San Carlos',
#   'Country': 'VE',
#   'Lat': 9.6612,
#   'Lng': -68.5827,
#   'Max Temp': 89.44,
#   'Humidity': 43,
#   'Cloudiness': 98,
#   'Wind Speed': 0.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Santo',
#   'Country': 'PT',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'North Port',
#   'Country': 'US',
#   'Lat': 27.0442,
#   'Lng': -82.2359,
#   'Max Temp': 75,
#   'Humidity': 49,
#   'Cloudiness': 62,
#   'Wind Speed': 7.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bolobo',
#   'Country': 'CD',
#   'Lat': -2.1667,
#   'Lng': 16.2333,
#   'Max Temp': 74.5,
#   'Humidity': 81,
#   'Cloudiness': 66,
#   'Wind Speed': 2.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salo',
#   'Country': 'IT',
#   'Lat': 45.6086,
#   'Lng': 10.531,
#   'Max Temp': 37.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Current Description': 'drizzle'},
#  {'City': 'Fern Creek',
#   'Country': 'US',
#   'Lat': 38.1598,
#   'Lng': -85.5877,
#   'Max Temp': 41,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Revda',
#   'Country': 'RU',
#   'Lat': 56.801,
#   'Lng': 59.9303,
#   'Max Temp': -0.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 13.42,
#   'Current Description': 'light snow'},
#  {'City': 'Khudumelapye',
#   'Country': 'BW',
#   'Lat': -23.8833,
#   'Lng': 24.75,
#   'Max Temp': 78.78,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tulum',
#   'Country': 'MX',
#   'Lat': 20.2167,
#   'Lng': -87.4667,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'light rain'},
#  {'City': 'Tiznit',
#   'Country': 'MA',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 55.24,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 4.59,
#   'Current Description': 'clear sky'},
#  {'City': 'Dombasle-Sur-Meurthe',
#   'Country': 'FR',
#   'Lat': 48.6252,
#   'Lng': 6.3497,
#   'Max Temp': 51.8,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 72.86,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 8.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gap',
#   'Country': 'FR',
#   'Lat': 44.6667,
#   'Lng': 6,
#   'Max Temp': 25.05,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nalut',
#   'Country': 'LY',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 49.53,
#   'Humidity': 48,
#   'Cloudiness': 32,
#   'Wind Speed': 9.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antsohihy',
#   'Country': 'MG',
#   'Lat': -14.8796,
#   'Lng': 47.9875,
#   'Max Temp': 74.26,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'light rain'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 24.8,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 6,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Lumeje',
#   'Country': 'AO',
#   'Lat': -11.55,
#   'Lng': 20.7833,
#   'Max Temp': 73.54,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kharp',
#   'Country': 'RU',
#   'Lat': 66.8014,
#   'Lng': 65.8081,
#   'Max Temp': -15.36,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Uzhur',
#   'Country': 'RU',
#   'Lat': 55.3036,
#   'Lng': 89.8339,
#   'Max Temp': -20.06,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 4.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Outjo',
#   'Country': 'NA',
#   'Lat': -20.1167,
#   'Lng': 16.15,
#   'Max Temp': 68.14,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 12.82,
#   'Current Description': 'moderate rain'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 6.8,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Maniwaki',
#   'Country': 'CA',
#   'Lat': 46.3834,
#   'Lng': -75.966,
#   'Max Temp': 10.4,
#   'Humidity': 61,
#   'Cloudiness': 79,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 74.61,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 19.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goias',
#   'Country': 'BR',
#   'Lat': -15.5807,
#   'Lng': -49.6362,
#   'Max Temp': 83.55,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 4.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Mednogorsk',
#   'Country': 'RU',
#   'Lat': 51.4128,
#   'Lng': 57.595,
#   'Max Temp': -6.2,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 6.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Orodara',
#   'Country': 'BF',
#   'Lat': 10.9492,
#   'Lng': -4.9342,
#   'Max Temp': 77,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 65.66,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 8.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Vallenar',
#   'Country': 'CL',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 85.64,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 11.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -22.83,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Canto Do Buriti',
#   'Country': 'BR',
#   'Lat': -8.11,
#   'Lng': -42.9444,
#   'Max Temp': 85.66,
#   'Humidity': 55,
#   'Cloudiness': 93,
#   'Wind Speed': 4.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kinsale',
#   'Country': 'IE',
#   'Lat': 51.7075,
#   'Lng': -8.5306,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sirjan',
#   'Country': 'IR',
#   'Lat': 29.452,
#   'Lng': 55.6814,
#   'Max Temp': 48.2,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 12.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Tamale',
#   'Country': 'GH',
#   'Lat': 9.4008,
#   'Lng': -0.8393,
#   'Max Temp': 84.54,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 6.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Bahia Honda',
#   'Country': 'CU',
#   'Lat': 22.9036,
#   'Lng': -83.1592,
#   'Max Temp': 74.55,
#   'Humidity': 67,
#   'Cloudiness': 5,
#   'Wind Speed': 13.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 76.55,
#   'Humidity': 67,
#   'Cloudiness': 98,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bell Ville',
#   'Country': 'AR',
#   'Lat': -32.6259,
#   'Lng': -62.6887,
#   'Max Temp': 98.42,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 11.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Bakchar',
#   'Country': 'RU',
#   'Lat': 57.0186,
#   'Lng': 82.0711,
#   'Max Temp': -16.06,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Royan',
#   'Country': 'FR',
#   'Lat': 45.6285,
#   'Lng': -1.0281,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moose Factory',
#   'Country': 'CA',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': -2.2,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 37,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Svetlyy',
#   'Country': 'RU',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 39.2,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 27.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Razdolnoye',
#   'Country': 'RU',
#   'Lat': 43.55,
#   'Lng': 131.9167,
#   'Max Temp': 19.4,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Beira',
#   'Country': 'MZ',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 84.2,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'moderate rain'},
#  {'City': 'San',
#   'Country': 'ML',
#   'Lat': 13.3034,
#   'Lng': -4.8956,
#   'Max Temp': 79.79,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Canutama',
#   'Country': 'BR',
#   'Lat': -6.5339,
#   'Lng': -64.3831,
#   'Max Temp': 78.69,
#   'Humidity': 92,
#   'Cloudiness': 81,
#   'Wind Speed': 1.95,
#   'Current Description': 'light rain'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arrifes',
#   'Country': 'PT',
#   'Lat': 37.7667,
#   'Lng': -25.7,
#   'Max Temp': 63,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'mist'},
#  {'City': 'Murgab',
#   'Country': 'TM',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 42.8,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Colares',
#   'Country': 'PT',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 57.99,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 68.79,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albion',
#   'Country': 'US',
#   'Lat': 42.2431,
#   'Lng': -84.753,
#   'Max Temp': 23,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 78.49,
#   'Humidity': 87,
#   'Cloudiness': 70,
#   'Wind Speed': 11.27,
#   'Current Description': 'light rain'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 63,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'mist'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'light rain'},
#  {'City': 'Benguela',
#   'Country': 'AO',
#   'Lat': -12.5763,
#   'Lng': 13.4055,
#   'Max Temp': 76.1,
#   'Humidity': 74,
#   'Cloudiness': 30,
#   'Wind Speed': 7.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Natal',
#   'Country': 'BR',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Boa Vista',
#   'Country': 'BR',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 89.6,
#   'Humidity': 40,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Current Description': 'few clouds'},
#  {'City': 'Muisne',
#   'Country': 'EC',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Mangan',
#   'Country': 'IN',
#   'Lat': 27.5167,
#   'Lng': 88.5333,
#   'Max Temp': 49.75,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nargana',
#   'Country': 'PA',
#   'Lat': 9.4428,
#   'Lng': -78.5906,
#   'Max Temp': 81.18,
#   'Humidity': 76,
#   'Cloudiness': 58,
#   'Wind Speed': 17.98,
#   'Current Description': 'light rain'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 28.62,
#   'Humidity': 85,
#   'Cloudiness': 93,
#   'Wind Speed': 5.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 36,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 11.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Polovinnoye',
#   'Country': 'RU',
#   'Lat': 54.7914,
#   'Lng': 65.9864,
#   'Max Temp': 1.11,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 14.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lusambo',
#   'Country': 'CD',
#   'Lat': -4.9667,
#   'Lng': 23.45,
#   'Max Temp': 73.31,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 10.4,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Mogadishu',
#   'Country': 'SO',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 79.12,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 21.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Quijarro',
#   'Country': 'BO',
#   'Lat': -17.7833,
#   'Lng': -57.7667,
#   'Max Temp': 92.05,
#   'Humidity': 46,
#   'Cloudiness': 88,
#   'Wind Speed': 2.19,
#   'Current Description': 'light rain'},
#  {'City': 'Bohdan',
#   'Country': 'UA',
#   'Lat': 48.0412,
#   'Lng': 24.3522,
#   'Max Temp': 32.31,
#   'Humidity': 94,
#   'Cloudiness': 96,
#   'Wind Speed': 4.43,
#   'Current Description': 'light snow'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 63.91,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 21.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Barentu',
#   'Country': 'ER',
#   'Lat': 15.1139,
#   'Lng': 37.5928,
#   'Max Temp': 57.56,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 51.55,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 15.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Firozpur',
#   'Country': 'IN',
#   'Lat': 30.9167,
#   'Lng': 74.6,
#   'Max Temp': 53.6,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'smoke'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 80.55,
#   'Humidity': 73,
#   'Cloudiness': 79,
#   'Wind Speed': 10.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Niamey',
#   'Country': 'NE',
#   'Lat': 13.5137,
#   'Lng': 2.1098,
#   'Max Temp': 78.8,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Conneaut',
#   'Country': 'US',
#   'Lat': 41.9476,
#   'Lng': -80.5542,
#   'Max Temp': 24.01,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tripoli',
#   'Country': 'LY',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 58.23,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 8.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 71.6,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp': -0.78,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light snow'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 70.92,
#   'Humidity': 58,
#   'Cloudiness': 22,
#   'Wind Speed': 7.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Ostersund',
#   'Country': 'SE',
#   'Lat': 63.1792,
#   'Lng': 14.6357,
#   'Max Temp': 23,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Current Description': 'snow'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 55.4,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Gnjilane',
#   'Country': 'XK',
#   'Lat': 42.4604,
#   'Lng': 21.4699,
#   'Max Temp': 35.01,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 1.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Opuwo',
#   'Country': 'NA',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 70.95,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 54.39,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 15.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 81,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'moderate rain'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 72.01,
#   'Humidity': 70,
#   'Cloudiness': 82,
#   'Wind Speed': 7.96,
#   'Current Description': 'broken clouds'},
#  {'City': 'Korycany',
#   'Country': 'CZ',
#   'Lat': 49.1064,
#   'Lng': 17.1643,
#   'Max Temp': 37.99,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto El Triunfo',
#   'Country': 'SV',
#   'Lat': 13.2833,
#   'Lng': -88.55,
#   'Max Temp': 96.8,
#   'Humidity': 32,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Sharlyk',
#   'Country': 'RU',
#   'Lat': 52.9167,
#   'Lng': 54.75,
#   'Max Temp': -5.08,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 6.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 77.07,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fuengirola',
#   'Country': 'ES',
#   'Lat': 36.54,
#   'Lng': -4.6247,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Briancon',
#   'Country': 'FR',
#   'Lat': 44.9,
#   'Lng': 6.65,
#   'Max Temp': 36,
#   'Humidity': 53,
#   'Cloudiness': 92,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buena Vista',
#   'Country': 'US',
#   'Lat': 43.4203,
#   'Lng': -83.8986,
#   'Max Temp': 25,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint Stephen',
#   'Country': 'GB',
#   'Lat': 50.3333,
#   'Lng': -4.9,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Current Description': 'drizzle'},
#  {'City': 'Mahon',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chake Chake',
#   'Country': 'TZ',
#   'Lat': -5.2459,
#   'Lng': 39.7666,
#   'Max Temp': 79.68,
# ...
#   'Cloudiness': 0,
#   'Wind Speed': 19.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Imbituba',
#   'Country': 'BR',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 1.4,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Surgut',
#   'Country': 'RU',
#   'Lat': 61.25,
#   'Lng': 73.4167,
#   'Max Temp': -18.4,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Qobustan',
#   'Country': 'AZ',
#   'Lat': 40.0824,
#   'Lng': 49.412,
#   'Max Temp': 37.4,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chernoyerkovskaya',
#   'Country': 'RU',
#   'Lat': 45.4331,
#   'Lng': 37.7686,
#   'Max Temp': 14,
#   'Humidity': 73,
#   'Cloudiness': 31,
#   'Wind Speed': 8.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cap-Aux-Meules',
#   'Country': 'CA',
#   'Lat': 47.3821,
#   'Lng': -61.8597,
#   'Max Temp': 21.2,
#   'Humidity': 68,
#   'Cloudiness': 25,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mikumi',
#   'Country': 'TZ',
#   'Lat': -7.4041,
#   'Lng': 36.9831,
#   'Max Temp': 71.47,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Current Description': 'moderate rain'},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 52,
#   'Humidity': 99,
#   'Cloudiness': 95,
#   'Wind Speed': 8.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lokoja',
#   'Country': 'NG',
#   'Lat': 7.8024,
#   'Lng': 6.743,
#   'Max Temp': 82.31,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 0.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Indiana',
#   'Country': 'US',
#   'Lat': 40.0003,
#   'Lng': -86.2503,
#   'Max Temp': 35.01,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 24.01,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Caraballeda',
#   'Country': 'VE',
#   'Lat': 10.6112,
#   'Lng': -66.8522,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Veraval',
#   'Country': 'IN',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 68.2,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 11.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Almeirim',
#   'Country': 'BR',
#   'Lat': -1.5233,
#   'Lng': -52.5817,
#   'Max Temp': 73.09,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Current Description': 'light rain'},
#  {'City': 'Mpika',
#   'Country': 'ZM',
#   'Lat': -11.8343,
#   'Lng': 31.4529,
#   'Max Temp': 63.86,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Current Description': 'light rain'},
#  {'City': 'Taybad',
#   'Country': 'IR',
#   'Lat': 34.74,
#   'Lng': 60.7756,
#   'Max Temp': 53.1,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 15.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Matay',
#   'Country': 'EG',
#   'Lat': 28.419,
#   'Lng': 30.7792,
#   'Max Temp': 48.36,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 11.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Bongandanga',
#   'Country': 'CD',
#   'Lat': 1.5,
#   'Lng': 21.05,
#   'Max Temp': 74.79,
#   'Humidity': 79,
#   'Cloudiness': 65,
#   'Wind Speed': 3.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pimentel',
#   'Country': 'PE',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Provins',
#   'Country': 'FR',
#   'Lat': 48.5833,
#   'Lng': 3.1667,
#   'Max Temp': 53.01,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ravar',
#   'Country': 'IR',
#   'Lat': 31.2656,
#   'Lng': 56.8055,
#   'Max Temp': 53.35,
#   'Humidity': 35,
#   'Cloudiness': 23,
#   'Wind Speed': 6.78,
#   'Current Description': 'few clouds'},
#  {'City': 'Khanskaya',
#   'Country': 'RU',
#   'Lat': 44.677,
#   'Lng': 39.9616,
#   'Max Temp': 17.49,
#   'Humidity': 94,
#   'Cloudiness': 9,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Putina',
#   'Country': 'PE',
#   'Lat': -15.4667,
#   'Lng': -69.4333,
#   'Max Temp': 53.4,
#   'Humidity': 64,
#   'Cloudiness': 61,
#   'Wind Speed': 17.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Monteagudo',
#   'Country': 'BO',
#   'Lat': -19.8167,
#   'Lng': -63.9833,
#   'Max Temp': 86,
#   'Humidity': 30,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Garowe',
#   'Country': 'SO',
#   'Lat': 8.4054,
#   'Lng': 48.4845,
#   'Max Temp': 73.51,
#   'Humidity': 70,
#   'Cloudiness': 69,
#   'Wind Speed': 14.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Visnes',
#   'Country': 'NO',
#   'Lat': 59.3556,
#   'Lng': 5.2242,
#   'Max Temp': 42.01,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Current Description': 'moderate rain'},
#  {'City': 'Mochudi',
#   'Country': 'BW',
#   'Lat': -24.4167,
#   'Lng': 26.15,
#   'Max Temp': 77,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Miraflores',
#   'Country': 'MX',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 69.8,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 4.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qovlar',
#   'Country': 'AZ',
#   'Lat': 40.948,
#   'Lng': 45.735,
#   'Max Temp': 32,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': -11.2,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 15.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Serenje',
#   'Country': 'ZM',
#   'Lat': -13.2325,
#   'Lng': 30.2352,
#   'Max Temp': 62.96,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baryshivka',
#   'Country': 'UA',
#   'Lat': 50.361,
#   'Lng': 31.3217,
#   'Max Temp': 12.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Loiza',
#   'Country': 'PR',
#   'Lat': 18.4313,
#   'Lng': -65.8802,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dornoch',
#   'Country': 'GB',
#   'Lat': 57.8805,
#   'Lng': -4.0288,
#   'Max Temp': 35.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'snow'},
#  {'City': 'Alekseyevka',
#   'Country': 'RU',
#   'Lat': 50.6309,
#   'Lng': 38.6903,
#   'Max Temp': -2.06,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Ngaoundere',
#   'Country': 'CM',
#   'Lat': 7.3167,
#   'Lng': 13.5833,
#   'Max Temp': 64.33,
#   'Humidity': 28,
#   'Cloudiness': 36,
#   'Wind Speed': 4.25,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Caconda',
#   'Country': 'AO',
#   'Lat': -13.7333,
#   'Lng': 15.0667,
#   'Max Temp': 60.98,
#   'Humidity': 52,
#   'Cloudiness': 43,
#   'Wind Speed': 6.53,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Abeche',
#   'Country': 'TD',
#   'Lat': 13.8292,
#   'Lng': 20.8324,
#   'Max Temp': 63.84,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 13.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Mamallapuram',
#   'Country': 'IN',
#   'Lat': 12.6264,
#   'Lng': 80.1722,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 8.37,
#   'Current Description': 'mist'},
#  {'City': 'Curico',
#   'Country': 'CL',
#   'Lat': -34.9833,
#   'Lng': -71.2333,
#   'Max Temp': 90,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahuva',
#   'Country': 'IN',
#   'Lat': 21.0914,
#   'Lng': 71.7622,
#   'Max Temp': 68.05,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 6.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Peto',
#   'Country': 'MX',
#   'Lat': 20.1333,
#   'Lng': -88.9167,
#   'Max Temp': 82.96,
#   'Humidity': 54,
#   'Cloudiness': 71,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lexington-Fayette',
#   'Country': 'US',
#   'Lat': 38.0498,
#   'Lng': -84.4585,
#   'Max Temp': 39.99,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'San Andres',
#   'Country': 'CO',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Chabahar',
#   'Country': 'IR',
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp': 69.12,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Kashi',
#   'Country': 'CN',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 24.8,
#   'Humidity': 68,
#   'Cloudiness': 60,
#   'Wind Speed': 6.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pital',
#   'Country': 'CO',
#   'Lat': 2.2665,
#   'Lng': -75.8044,
#   'Max Temp': 83.28,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 78.89,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Murmashi',
#   'Country': 'RU',
#   'Lat': 68.8154,
#   'Lng': 32.8115,
#   'Max Temp': -7.6,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'fog'},
#  {'City': 'Oktyabrskiy',
#   'Country': 'RU',
#   'Lat': 54.4815,
#   'Lng': 53.471,
#   'Max Temp': -5.22,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gwanda',
#   'Country': 'ZW',
#   'Lat': -20.9333,
#   'Lng': 29,
#   'Max Temp': 70.09,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 10.83,
#   'Current Description': 'light rain'},
#  {'City': 'Ilhabela',
#   'Country': 'BR',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 79.57,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 2.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kardamaina',
#   'Country': 'GR',
#   'Lat': 36.7814,
#   'Lng': 27.1425,
#   'Max Temp': 46.4,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Sistranda',
#   'Country': 'NO',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 33.8,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 29.93,
#   'Current Description': 'light snow'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 91.99,
#   'Humidity': 42,
#   'Cloudiness': 3,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Kizema',
#   'Country': 'RU',
#   'Lat': 61.113,
#   'Lng': 44.8302,
#   'Max Temp': -1.55,
#   'Humidity': 93,
#   'Cloudiness': 77,
#   'Wind Speed': 5.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Syracuse',
#   'Country': 'IT',
#   'Lat': 37.0881,
#   'Lng': 15.2792,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 73.99,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Sabha',
#   'Country': 'LY',
#   'Lat': 27.0377,
#   'Lng': 14.4283,
#   'Max Temp': 49.28,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 6.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Probistip',
#   'Country': 'MK',
#   'Lat': 42.0031,
#   'Lng': 22.1786,
#   'Max Temp': 24.8,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 1.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Casablanca',
#   'Country': 'MA',
#   'Lat': 33.5928,
#   'Lng': -7.6192,
#   'Max Temp': 59,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urengoy',
#   'Country': 'RU',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp': -34.67,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Diamantino',
#   'Country': 'BR',
#   'Lat': -14.4086,
#   'Lng': -56.4461,
#   'Max Temp': 83.1,
#   'Humidity': 75,
#   'Cloudiness': 84,
#   'Wind Speed': 5.1,
#   'Current Description': 'moderate rain'},
#  {'City': 'Acari',
#   'Country': 'PE',
#   'Lat': -15.4311,
#   'Lng': -74.6158,
#   'Max Temp': 82.11,
#   'Humidity': 47,
#   'Cloudiness': 54,
#   'Wind Speed': 10.69,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 83.77,
#   'Humidity': 13,
#   'Cloudiness': 36,
#   'Wind Speed': 7.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 78.53,
#   'Humidity': 73,
#   'Cloudiness': 80,
#   'Wind Speed': 12.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 23,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ondangwa',
#   'Country': 'NA',
#   'Lat': -17.9167,
#   'Lng': 15.95,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 21.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Mtwara',
#   'Country': 'TZ',
#   'Lat': -10.2667,
#   'Lng': 40.1833,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 17.6,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bhanpura',
#   'Country': 'IN',
#   'Lat': 24.513,
#   'Lng': 75.7469,
#   'Max Temp': 63.66,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Kashan',
#   'Country': 'IR',
#   'Lat': 33.9831,
#   'Lng': 51.4364,
#   'Max Temp': 48.29,
#   'Humidity': 48,
#   'Cloudiness': 8,
#   'Wind Speed': 3.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Mercedes',
#   'Country': 'AR',
#   'Lat': -34.6515,
#   'Lng': -59.4307,
#   'Max Temp': 91.99,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Kathmandu',
#   'Country': 'NP',
#   'Lat': 27.7167,
#   'Lng': 85.3167,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'mist'},
#  {'City': 'Sibenik',
#   'Country': 'HR',
#   'Lat': 43.7272,
#   'Lng': 15.9058,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Roda',
#   'Country': 'ES',
#   'Lat': 39.2167,
#   'Lng': -2.15,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marystown',
#   'Country': 'CA',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 25.92,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Truro',
#   'Country': 'GB',
#   'Lat': 50.2653,
#   'Lng': -5.0544,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Current Description': 'drizzle'}]

# %%
# Convert list of dictionaries into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Muskegon      US  43.3000 -86.1334     27.00        68          90
# 1        Jamestown      US  42.0970 -79.2353     21.99        73          90
# 2             Faya      SA  18.3851  42.4509     55.40        82           0
# 3          Ushuaia      AR -54.8000 -68.3000     59.00        41          40
# 4         Hermanus      ZA -34.4187  19.2345     66.99        77           2
# 5     Punta Arenas      CL -53.1500 -70.9167     60.80        44           0
# 6            Kuryk      KZ  43.2000  51.6500     28.76        85          58
# 7         West Bay      KY  19.3667 -81.4167     79.00        78          75
# 8  Puerto Colombia      CO  10.9878 -74.9547     86.00        66          20
# 9         Valdivia      CL -39.8142 -73.2459     89.60        33           0
#
#    Wind Speed Current Description
# 0       17.27     overcast clouds
# 1       17.27          light snow
# 2        5.75           clear sky
# 3        4.61    scattered clouds
# 4        4.00           clear sky
# 5       20.71           clear sky
# 6       17.74       broken clouds
# 7       14.97       broken clouds
# 8       14.97          few clouds
# 9        9.22           clear sky

# %%
# Create the output file to CSV
output_data_file = "Weather_Database/cities.csv"
# Export the city_data_df into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
